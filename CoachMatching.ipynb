# %%
# Coach and Team Data Preview Notebook

import pandas as pd

# Set display options to show all columns
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)

# Function to load and preview first 50 rows
def preview_dataset(file_path, dataset_name, n_rows=50):
    try:
        # Try reading as Excel first
        df = pd.read_excel(file_path, nrows=n_rows)
    except:
        try:
            # If Excel fails, try CSV
            df = pd.read_csv(file_path, nrows=n_rows)
        except Exception as e:
            print(f"Error reading {dataset_name} dataset: {str(e)}")
            return None
    
    print(f"\n{'='*50}")
    print(f"Preview of {dataset_name} dataset (first {n_rows} rows)")
    print(f"Shape: {df.shape}")
    print(f"Columns: {list(df.columns)}")
    print(f"{'='*50}\n")
    
    return df

# Load your datasets (replace with your actual file paths)
coaches_path = "C:/Users/hamou/Downloads/data/male_coaches.csv"  # Replace with your actual path
teams_path = "C:/Users/hamou/Downloads/data/male_teams.csv"      # Replace with your actual path

# Preview coaches data
coaches_df = preview_dataset(coaches_path, "Coaches")

# Preview teams data
teams_df = preview_dataset(teams_path, "Teams")

# Show basic info about each dataset
if coaches_df is not None:
    print("\nCoaches Dataset Info:")
    print(coaches_df.info())
    display(coaches_df.head(50))

if teams_df is not None:
    print("\nTeams Dataset Info:")
    print(teams_df.info())
    display(teams_df.head(50))
# Out:
# ==================================================
# Preview of Coaches dataset (first 50 rows)
# Shape: (50, 8)
# Columns: ['coach_id', 'coach_url', 'short_name', 'long_name', 'dob', 'nationality_id', 'nationality_name', 'face_url']
# ==================================================
#
#
# ==================================================
# Preview of Teams dataset (first 50 rows)
# Shape: (50, 54)
# Columns: ['team_id', 'team_url', 'fifa_version', 'fifa_update', 'fifa_update_date', 'team_name', 'league_id', 'league_name', 'league_level', 'nationality_id', 'nationality_name', 'overall', 'attack', 'midfield', 'defence', 'coach_id', 'home_stadium', 'rival_team', 'international_prestige', 'domestic_prestige', 'transfer_budget_eur', 'club_worth_eur', 'starting_xi_average_age', 'whole_team_average_age', 'captain', 'short_free_kick', 'long_free_kick', 'left_short_free_kick', 'right_short_free_kick', 'penalties', 'left_corner', 'right_corner', 'def_style', 'def_team_width', 'def_team_depth', 'def_defence_pressure', 'def_defence_aggression', 'def_defence_width', 'def_defence_defender_line', 'off_style', 'off_build_up_play', 'off_chance_creation', 'off_team_width', 'off_players_in_box', 'off_corners', 'off_free_kicks', 'build_up_play_speed', 'build_up_play_dribbling', 'build_up_play_passing', 'build_up_play_positioning', 'chance_creation_passing', 'chance_creation_crossing', 'chance_creation_shooting', 'chance_creation_positioning']
# ==================================================
#
#
# Coaches Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   coach_id          50 non-null     int64
#  1   coach_url         50 non-null     object
#  2   short_name        50 non-null     object
#  3   long_name         50 non-null     object
#  4   dob               50 non-null     object
#  5   nationality_id    50 non-null     int64
#  6   nationality_name  50 non-null     object
#  7   face_url          28 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ KB
# None
#     coach_id                            coach_url           short_name               long_name         dob  nationality_id     nationality_name                                           face_url
# 0         24            /coach/24/david-unsworth/          D. Unsworth          David Unsworth  1973-10-16              14              England                                                NaN
# 1         50            /coach/50/steven-gerrard/           S. Gerrard          Steven Gerrard  1980-05-30              14              England  https://cdn.sportmonks.com/images/soccer/playe...
# 2         95             /coach/95/frank-lampard/           F. Lampard           Frank Lampard  1978-06-20              14              England  https://cdn.sportmonks.com/images/soccer/playe...
# 3        121            /coach/121/carl-hoefkens/          C. Hoefkens           Carl Hoefkens  1978-10-05               7              Belgium  https://cdn.sportmonks.com/images//soccer/coac...
# 4        123      /coach/123/matthew-etherington/       M. Etherington     Matthew Etherington  1981-08-14              14              England  https://cdn.sportmonks.com/images/soccer/playe...
# 5        126              /coach/126/andy-dawson/            A. Dawson             Andy Dawson  1978-10-20              14              England                                                NaN
# 6        204            /coach/204/ki-hyeon-seol/              K. Seol           Ki-Hyeon Seol  1979-01-08             167       Korea Republic  https://cdn.sportmonks.com/images/soccer/playe...
# 7        236          /coach/236/vincent-kompany/           V. Kompany         Vincent Kompany  1986-04-10               7              Belgium  https://cdn.sportmonks.com/images/soccer/playe...
# 8        252     /coach/252/carlos-alberto-tevez/             C. Tevez    Carlos Alberto Tevez  1984-02-05              52            Argentina  https://cdn.sportmonks.com/images/soccer/playe...
# 9        270               /coach/270/gary-oneil/            G. O'Neil             Gary O'Neil  1983-05-18              14              England                                                NaN
# 10       305             /coach/305/phil-neville/           P. Neville            Phil Neville  1977-01-21              14              England  https://cdn.sportmonks.com/images//soccer/coac...
# 11       307   /coach/307/mikel-arteta-amatriain/            M. Arteta  Mikel Arteta Amatriain  1982-03-26              45                Spain  https://cdn.sportmonks.com/images/soccer/playe...
# 12       380           /coach/380/emre-belozoglu/         E. Belözoğlu          Emre Belözoğlu  1980-09-07              48               Turkey  https://cdn.sportmonks.com/images/soccer/playe...
# 13       382              /coach/382/damien-duff/              D. Duff             Damien Duff  1979-03-02              25  Republic of Ireland  https://cdn.sportmonks.com/images/soccer/playe...
# 14       384             /coach/384/darren-moore/             D. Moore            Darren Moore  1974-04-22              14              England                                                NaN
# 15       468             /coach/468/wade-elliott/           W. Elliott            Wade Elliott  1978-12-14              14              England  https://cdn.sportmonks.com/images/soccer/playe...
# 16       491           /coach/491/ian-ross-evatt/             I. Evatt          Ian Ross Evatt  1981-11-19              14              England                                                NaN
# 17       497               /coach/497/dirk-kuijt/             D. Kuijt              Dirk Kuijt  1980-07-22              34          Netherlands  https://cdn.sportmonks.com/images/soccer/playe...
# 18       511      /coach/511/xabier-alonso-olano/      X. Alonso Olano     Xabier Alonso Olano  1981-11-25              45                Spain  https://cdn.sportmonks.com/images/soccer/playe...
# 19       562              /coach/562/rob-edwards/           R. Edwards             Rob Edwards  1982-12-25              50                Wales                                                NaN
# 20       579        /coach/579/wayne-mark-rooney/            W. Rooney       Wayne Mark Rooney  1985-10-24              14              England  https://cdn.sportmonks.com/images/soccer/playe...
# 21       607          /coach/607/gary-mcsheffrey/        G. McSheffrey         Gary McSheffrey  1982-08-13              14              England                                                NaN
# 22       611              /coach/611/mehdi-nafti/             M. Nafti             Mehdi Nafti  1978-11-28             145              Tunisia                                                NaN
# 23       618            /coach/618/liam-rosenior/          L. Rosenior           Liam Rosenior  1984-07-09              14              England  https://cdn.sportmonks.com/images/soccer/playe...
# 24       645          /coach/645/michael-carrick/           M. Carrick         Michael Carrick  1981-07-28              14              England  https://cdn.sportmonks.com/images/soccer/playe...
# 25       658              /coach/658/joey-barton/            J. Barton             Joey Barton  1982-09-02              14              England  https://cdn.sportmonks.com/images/soccer/playe...
# 26       684          /coach/684/nick-montgomery/        N. Montgomery         Nick Montgomery  1981-10-28              42             Scotland  https://cdn.sportmonks.com/images/soccer/playe...
# 27       781            /coach/781/gary-caldwell/          G. Caldwell           Gary Caldwell  1982-04-12              42             Scotland                                                NaN
# 28       869            /coach/869/steve-morison/           S. Morison           Steve Morison  1983-08-29              50                Wales  https://cdn.sportmonks.com/images/soccer/playe...
# 29       904           /coach/904/russell-martin/            R. Martin          Russell Martin  1986-01-04              42             Scotland  https://cdn.sportmonks.com/images/soccer/playe...
# 30      1198            /coach/1198/kelvin-davis/             K. Davis            Kelvin Davis  1976-09-29              14              England  https://cdn.sportmonks.com/images/soccer/playe...
# 31      1260             /coach/1260/mark-hudson/            M. Hudson             Mark Hudson  1982-03-30              14              England                                                NaN
# 32      1458            /coach/1458/michael-duff/              M. Duff            Michael Duff  1978-01-11              35     Northern Ireland  https://cdn.sportmonks.com/images/soccer/playe...
# 33      1600             /coach/1600/lee-johnson/           L. Johnson             Lee Johnson  1981-06-07              14              England                                                NaN
# 34      1621             /coach/1621/jim-goodwin/           J. Goodwin             Jim Goodwin  1981-11-20              25  Republic of Ireland                                                NaN
# 35      1631        /coach/1631/patrick-kisnorbo/          P. Kisnorbo        Patrick Kisnorbo  1981-03-24             195            Australia  https://cdn.sportmonks.com/images/soccer/playe...
# 36      1713               /coach/1713/zhi-zheng/             Z. Zheng               Zhi Zheng  1980-08-20             155             China PR  https://cdn.sportmonks.com/images/soccer/playe...
# 37      1742         /coach/1742/callum-davidson/          C. Davidson         Callum Davidson  1976-06-25              42             Scotland  https://cdn.sportmonks.com/images/soccer/playe...
# 38      1749            /coach/1749/grant-mccann/            G. McCann            Grant McCann  1980-04-14              35     Northern Ireland  https://cdn.sportmonks.com/images/soccer/playe...
# 39      1773             /coach/1773/wayne-brown/             W. Brown             Wayne Brown  1977-08-20              14              England                                                NaN
# 40      1819        /coach/1819/gareth-ainsworth/         G. Ainsworth        Gareth Ainsworth  1973-05-10              14              England                                                NaN
# 41      2003         /coach/2003/johnnie-jackson/           J. Jackson         Johnnie Jackson  1982-08-15              14              England  https://cdn.sportmonks.com/images/soccer/playe...
# 42      2103         /coach/2103/richard-wellens/           R. Wellens         Richard Wellens  1980-03-26              14              England                                                NaN
# 43      2133      /coach/2133/michael-john-flynn/             M. Flynn      Michael John Flynn  1980-10-17              50                Wales                                                NaN
# 44      2146            /coach/2146/john-eustace/           J. Eustace            John Eustace  1979-11-03              14              England                                                NaN
# 45      2151       /coach/2151/mark-fotheringham/      M. Fotheringham       Mark Fotheringham  1983-10-22              42             Scotland                                                NaN
# 46      2198            /coach/2198/mark-kennedy/           M. Kennedy            Mark Kennedy  1976-05-15              25  Republic of Ireland                                                NaN
# 47      2615             /coach/2615/colin-healy/             C. Healy             Colin Healy  1980-03-15              25  Republic of Ireland                                                NaN
# 48      2665  /coach/2665/david-gonzalez-giraldo/  D. González Giraldo  David González Giraldo  1982-07-20              56             Colombia                                                NaN
# 49      2733          /coach/2733/matthew-taylor/            M. Taylor          Matthew Taylor  1982-01-30              14              England                                                NaN
# Teams Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 54 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   team_id                      50 non-null     int64
#  1   team_url                     50 non-null     object
#  2   fifa_version                 50 non-null     int64
#  3   fifa_update                  50 non-null     int64
#  4   fifa_update_date             50 non-null     object
#  5   team_name                    50 non-null     object
#  6   league_id                    50 non-null     int64
#  7   league_name                  50 non-null     object
#  8   league_level                 38 non-null     float64
#  9   nationality_id               50 non-null     int64
#  10  nationality_name             50 non-null     object
#  11  overall                      50 non-null     int64
#  12  attack                       50 non-null     int64
#  13  midfield                     50 non-null     int64
#  14  defence                      50 non-null     int64
#  15  coach_id                     50 non-null     int64
#  16  home_stadium                 50 non-null     object
#  17  rival_team                   50 non-null     int64
#  18  international_prestige       50 non-null     int64
#  19  domestic_prestige            38 non-null     float64
#  20  transfer_budget_eur          0 non-null      float64
#  21  club_worth_eur               38 non-null     float64
#  22  starting_xi_average_age      50 non-null     float64
#  23  whole_team_average_age       50 non-null     float64
#  24  captain                      50 non-null     int64
#  25  short_free_kick              50 non-null     int64
#  26  long_free_kick               50 non-null     int64
#  27  left_short_free_kick         50 non-null     int64
#  28  right_short_free_kick        50 non-null     int64
#  29  penalties                    50 non-null     int64
#  30  left_corner                  50 non-null     int64
#  31  right_corner                 50 non-null     int64
#  32  def_style                    50 non-null     object
#  33  def_team_width               50 non-null     int64
#  34  def_team_depth               50 non-null     int64
#  35  def_defence_pressure         0 non-null      float64
#  36  def_defence_aggression       0 non-null      float64
#  37  def_defence_width            0 non-null      float64
#  38  def_defence_defender_line    0 non-null      float64
#  39  off_style                    0 non-null      float64
#  40  off_build_up_play            50 non-null     object
#  41  off_chance_creation          50 non-null     object
#  42  off_team_width               50 non-null     int64
#  43  off_players_in_box           50 non-null     int64
#  44  off_corners                  50 non-null     int64
#  45  off_free_kicks               50 non-null     int64
#  46  build_up_play_speed          0 non-null      float64
#  47  build_up_play_dribbling      0 non-null      float64
#  48  build_up_play_passing        0 non-null      float64
#  49  build_up_play_positioning    0 non-null      float64
#  50  chance_creation_passing      0 non-null      float64
#  51  chance_creation_crossing     0 non-null      float64
#  52  chance_creation_shooting     0 non-null      float64
#  53  chance_creation_positioning  0 non-null      float64
# dtypes: float64(19), int64(26), object(9)
# memory usage: 21.2+ KB
# None
#     team_id                                  team_url  fifa_version  fifa_update fifa_update_date                 team_name  league_id             league_name  league_level  nationality_id nationality_name  overall  attack  midfield  defence  coach_id                          home_stadium  rival_team  international_prestige  domestic_prestige  transfer_budget_eur  club_worth_eur  starting_xi_average_age  whole_team_average_age  captain  short_free_kick  long_free_kick  left_short_free_kick  right_short_free_kick  penalties  left_corner  right_corner                    def_style  def_team_width  def_team_depth  def_defence_pressure  def_defence_aggression  def_defence_width  def_defence_defender_line  off_style off_build_up_play off_chance_creation  off_team_width  off_players_in_box  off_corners  off_free_kicks  build_up_play_speed  build_up_play_dribbling  build_up_play_passing  build_up_play_positioning  chance_creation_passing  chance_creation_crossing  chance_creation_shooting  \
# 0        10           /team/10/manchester-city/230009            23            9       2023-01-13           Manchester City         13          Premier League           1.0              14          England       85      85        86       86    455361                        Etihad Stadium          11                      10               10.0                  NaN   -2.147484e+09                    27.09                   25.88   186942           192985          192985                192985                 192985     192985       192985        237692  Press After Possession Loss              71              81                   NaN                     NaN                NaN                        NaN        NaN     Slow Build Up          Possession              71                   6            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 1        73       /team/73/paris-saint-germain/230009            23            9       2023-01-13       Paris Saint Germain         16                 Ligue 1           1.0              18           France       85      87        83       83    524011                      Parc des Princes         219                       9               10.0                  NaN   -2.147484e+09                    26.82                   26.04   207865           190871          158023                190871                 158023     190871       190871        190871  Press After Possession Loss              61              71                   NaN                     NaN                NaN                        NaN        NaN     Slow Build Up          Possession              41                   8            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 2       243              /team/243/real-madrid/230009            23            9       2023-01-13               Real Madrid         53                 La Liga           1.0              45            Spain       85      85        86       84    455800             Estadio Santiago Bernabéu         241                      10               10.0                  NaN   -2.147484e+09                    28.55                   24.64   165153           182521          182521                182521                 197445     165153       182521        182521                     Balanced              51              71                   NaN                     NaN                NaN                        NaN        NaN          Balanced            Balanced              51                   6            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 3      1337                 /team/1337/germany/230009            23            9       2023-01-13                   Germany         78  Friendly International           NaN              21          Germany       85      82        85       82  37352367                       Stadion Olympik        1318                      10                NaN                  NaN             NaN                    28.27                   27.22   167495           186942          212622                186942                 186942     186942       212622        212622      Pressure On Heavy Touch              61              61                   NaN                     NaN                NaN                        NaN        NaN     Fast Build Up        Forward Runs              61                   6            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 4         5                    /team/5/chelsea/230009            23            9       2023-01-13                   Chelsea         13          Premier League           1.0              14          England       84      83        83       83    452683                       Stamford Bridge           1                       8                9.0                  NaN   -2.147484e+09                    26.73                   24.55   205498           233064          233064                233064                 233064     205498       233064        233064                     Balanced              61              71                   NaN                     NaN                NaN                        NaN        NaN     Slow Build Up          Possession              61                   5            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 5         9                  /team/9/liverpool/230009            23            9       2023-01-13                 Liverpool         13          Premier League           1.0              14          England       84      84        82       86    455353                               Anfield          11                       9                9.0                  NaN   -2.147484e+09                    26.73                   25.03   203376           231281          231281                231281                 231281     209331       216267        231281  Press After Possession Loss              61              71                   NaN                     NaN                NaN                        NaN        NaN          Balanced            Balanced              71                   5            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 6        21         /team/21/fc-bayern-munchen/230009            23            9       2023-01-13         FC Bayern München         19              Bundesliga           1.0              21          Germany       84      78        86       83    458813  Sanderson Park (FIFA 13 NEW generic)          22                      10               10.0                  NaN   -2.147484e+09                    26.09                   25.04   212622           212622          212622                208722                 212622     208722       212622        212622      Pressure On Heavy Touch              41              81                   NaN                     NaN                NaN                        NaN        NaN     Slow Build Up          Possession              81                   8            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 7       241             /team/241/fc-barcelona/230009            23            9       2023-01-13              FC Barcelona         53                 La Liga           1.0              45            Spain       84      84        85       82    184942         El Libertador (La Bombastico)         243                      10               10.0                  NaN   -2.147484e+09                    26.36                   23.55   189511           188545          251854                188545                 188545     188545       231443        231443                     Balanced              61              81                   NaN                     NaN                NaN                        NaN        NaN     Slow Build Up          Possession              51                   7            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 8      1318                 /team/1318/england/230009            23            9       2023-01-13                   England         78  Friendly International           NaN              14          England       84      85        83       83    474589                       Wembley Stadium        1337                       8                NaN                  NaN             NaN                    26.55                   25.91   202126           233064          202126                233064                 233064     202126       237692        233064                     Balanced              61              61                   NaN                     NaN                NaN                        NaN        NaN     Slow Build Up          Possession              71                   4            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 9        44                     /team/44/inter/230009            23            9       2023-01-13                     Inter         31                 Serie A           1.0              27            Italy       83      85        83       83    128160                              San Siro          47                       7                9.0                  NaN    9.490000e+08                    27.45                   27.25   232363           208128          208128                208128                 208128     231478       208128        208128                     Balanced              51              61                   NaN                     NaN                NaN                        NaN        NaN     Fast Build Up        Forward Runs              51                   4            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 10     1335                  /team/1335/france/230009            23            9       2023-01-13                    France         78  Friendly International           NaN              18           France       83      84        83       83    474616                      Orange Vélodrome        1343                      10                NaN                  NaN             NaN                    26.18                   25.61   201535           194765          194765                194765                 194765     231747       194765        194765      Pressure On Heavy Touch              71              61                   NaN                     NaN                NaN                        NaN        NaN          Balanced            Balanced              71                   5            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 11     1343                   /team/1343/italy/230009            23            9       2023-01-13                     Italy         78  Friendly International           NaN              27            Italy       83      83        84       82    784486                       Stadion Olympik        1335                       9                NaN                  NaN             NaN                    27.91                   27.57   184344           205498          205498                205498                 205498     205498       199556        205498      Pressure On Heavy Touch              51              51                   NaN                     NaN                NaN                        NaN        NaN          Balanced            Balanced              61                   3            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 12     1354                /team/1354/portugal/230009            23            9       2023-01-13                  Portugal         78  Friendly International           NaN              38         Portugal       83      85        82       84    896314         Waldstadion (Fussballstadion)        1362                       8                NaN                  NaN             NaN                    29.36                   26.96    20801            20801           20801                 20801                  20801      20801       212198        218667                     Balanced              41              51                   NaN                     NaN                NaN                        NaN        NaN          Balanced            Balanced              41                   3            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 13     1362                   /team/1362/spain/230009            23            9       2023-01-13                     Spain         78  Friendly International           NaN              45            Spain       83      82        83       82    523959                   Wanda Metropolitano        1343                       9                NaN                  NaN             NaN                    24.36                   25.35   189332           241461          241461                241461                 241461     241461       244260        220834      Pressure On Heavy Touch              61              71                   NaN                     NaN                NaN                        NaN        NaN     Slow Build Up          Possession              71                   7            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 14     1369               /team/1369/argentina/230009            23            9       2023-01-13                 Argentina         78  Friendly International           NaN              52        Argentina       83      84        82       82    127611                          La Bombonera        1337                       9                NaN                  NaN             NaN                    28.09                   27.74   158023           158023          158023                158023                 158023     158023       158023        158023                     Balanced              41              51                   NaN                     NaN                NaN                        NaN        NaN     Slow Build Up          Possession              41                   6            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 15       11         /team/11/manchester-united/230009            23            9       2023-01-13         Manchester United         13          Premier League           1.0              14          England       82      81        83       81    456113                          Old Trafford           9                       8                8.0                  NaN   -2.147484e+09                    26.55                   24.48   212198           190460          190460                190460                 190460     212198       190460        205988      Pressure On Heavy Touch              41              51                   NaN                     NaN                NaN                        NaN        NaN     Slow Build Up          Possession              61                   4            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 16       45                  /team/45/juventus/230009            23            9       2023-01-13                  Juventus         31                 Serie A           1.0              27            Italy       82      83        80       81    455957                        Juventus Arena          44                       9               10.0                  NaN   -2.147484e+09                    27.91                   25.65   184344           246430          193082                246430                 246430     246430       193082        193082      Pressure On Heavy Touch              51              41                   NaN                     NaN                NaN                        NaN        NaN         Long Ball      Direct Passing              61                   3            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 17      240          /team/240/atletico-madrid/230009            23            9       2023-01-13           Atlético Madrid         53                 La Liga           1.0              45            Spain       82      83        83       81    452946                   Wanda Metropolitano         243                       9                9.0                  NaN    1.200000e+09                    28.36                   25.00   193747           208418          208418                208418                 208418     208418       208418        208418      Pressure On Heavy Touch              61              61                   NaN                     NaN                NaN                        NaN        NaN          Balanced            Balanced              51                   3            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 18     1325                 /team/1325/belgium/230009            23            9       2023-01-13                   Belgium         78  Friendly International           NaN               7          Belgium       82      86        80       79    474796                               O Dromo      105035                       8                NaN                  NaN             NaN                    29.36                   28.65   183277           192985          192985                192985                 192985     192505       192985        192985      Pressure On Heavy Touch              61              71                   NaN                     NaN                NaN                        NaN        NaN     Slow Build Up          Possession              61                   6            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 19   105035           /team/105035/netherlands/230009            23            9       2023-01-13               Netherlands         78  Friendly International           NaN              34      Netherlands       82      83        82       82  37523072                   Johan Cruijff ArenA        1337                       8                NaN                  NaN             NaN                    26.82                   27.17   203376           202556          202556                202556                 202556     202556       202556        202556                     Balanced              51              61                   NaN                     NaN                NaN                        NaN        NaN     Fast Build Up        Forward Runs              61                   4            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 20       18         /team/18/tottenham-hotspur/230009            23            9       2023-01-13         Tottenham Hotspur         13          Premier League           1.0              14          England       81      83        81       79    455384             Tottenham Hotspur Stadium           1                       7                8.0                  NaN   -2.147484e+09                    27.45                   24.97   167948           200104          200104                200104                 200104     202126       200104        181458                     Balanced              61              41                   NaN                     NaN                NaN                        NaN        NaN          Balanced            Balanced              61                   4            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 21       22         /team/22/borussia-dortmund/230009            23            9       2023-01-13         Borussia Dortmund         19              Bundesliga           1.0              21          Germany       81      78        81       81    417317                     Signal Iduna Park          34                       7                9.0                  NaN    1.700000e+09                    24.73                   24.09   188350           188350          209889                188350                 209889     188350       209889        209889  Press After Possession Loss              51              81                   NaN                     NaN                NaN                        NaN        NaN     Fast Build Up        Forward Runs              41                   6            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 22       47                     /team/47/milan/230009            23            9       2023-01-13                     Milan         31                 Serie A           1.0              27            Italy       81      80        81       80    459100                              San Siro          44                       7                9.0                  NaN    1.100000e+09                    25.91                   25.87   232656           241096          241096                241096                 241096     232656       241096        241096      Pressure On Heavy Touch              51              61                   NaN                     NaN                NaN                        NaN        NaN     Fast Build Up        Forward Runs              51                   8            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 23      481                  /team/481/sevilla/230009            23            9       2023-01-13                   Sevilla         53                 La Liga           1.0              45            Spain       81      79        82       80    456014                 Ramón Sánchez-Pizjuán         449                       8                8.0                  NaN    5.400000e+08                    28.91                   26.60   168651           224309          224309                224309                 224309     231628       224309        224309      Pressure On Heavy Touch              71              71                   NaN                     NaN                NaN                        NaN        NaN     Slow Build Up          Possession              81                   8            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 24   112172            /team/112172/rb-leipzig/230009            23            9       2023-01-13                RB Leipzig         19              Bundesliga           1.0              21          Germany       81      83        81       80     29710              Red Bull Arena (Leipzig)          22                       7                8.0                  NaN    4.912000e+08                    25.64                   25.36   204638           232411          232411                232411                 232411     232411       236703        236703  Press After Possession Loss              51              71                   NaN                     NaN                NaN                        NaN        NaN          Balanced            Balanced              51                   4            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 25        1                    /team/1/arsenal/230009            23            9       2023-01-13                   Arsenal         13          Premier League           1.0              14          England       80      82        82       79       307                      Emirates Stadium          18                       7                7.0                  NaN    2.000000e+09                    24.09                   22.97   222665           222665          222665                222665                 222665     246669       251566        246669                     Balanced              51              61                   NaN                     NaN                NaN                        NaN        NaN     Slow Build Up          Possession              61                   5            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 26       32       /team/32/bayer-04-leverkusen/230009            23            9       2023-01-13       Bayer 04 Leverkusen         19              Bundesliga           1.0              21          Germany       80      81        79       79       511                              BayArena          31                       6                8.0                  NaN    4.458000e+08                    24.36                   24.00   190941           211748          211748                211748                 211748     241852       211748        211748  Press After Possession Loss              51              71                   NaN                     NaN                NaN                        NaN        NaN          Balanced            Balanced              71                   4            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 27       48                    /team/48/napoli/230009            23            9       2023-01-13                    Napoli         31                 Serie A           1.0              27            Italy       80      80        81       80    523897                       Stadion Olympik          45                       7                9.0                  NaN    5.900000e+08                    26.18                   25.73   217870           204614          204614                204614                 204614     232293       210406        210406                     Balanced              61              61                   NaN                     NaN                NaN                        NaN        NaN     Fast Build Up        Forward Runs              61                   6            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 28       52                      /team/52/roma/230009            23            9       2023-01-13                      Roma         31                 Serie A           1.0              27            Italy       80      82        79       81    455375                       Stadion Olympik          46                       7                8.0                  NaN    6.020000e+08                    26.09                   24.81   228251           228251          228251                228251                 228251     228251       228251        228251                     Balanced              61              41                   NaN                     NaN                NaN                        NaN        NaN     Slow Build Up          Possession              61                   5            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 29      483               /team/483/villarreal/230009            23            9       2023-01-13                Villarreal         53                 La Liga           1.0              45            Spain       80      82        80       79    459056                Estadio de la Cerámica         461                       7                8.0                  NaN    3.700000e+08                    30.82                   27.46   157481           189513          189513                189513                 189513     208093       189513        189513                     Balanced              61              51                   NaN                     NaN                NaN                        NaN        NaN          Balanced            Balanced              61                   5            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 30     1328                 /team/1328/croatia/230009            23            9       2023-01-13                   Croatia         78  Friendly International           NaN              10          Croatia       80      79        83       78    896785                        Stadion Hanguk        1886                       6                NaN                  NaN             NaN                    28.45                   27.43   177003           177003          177003                177003                 177003     216354       177003        177003                     Balanced              61              71                   NaN                     NaN                NaN                        NaN        NaN     Slow Build Up          Possession              61                   4            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# ...
# 36       46                     /team/46/lazio/230009            23            9       2023-01-13                     Lazio         31                 Serie A           1.0              27            Italy       79      80        79       78    455926                       Stadion Olympik          52                       6                7.0                  NaN    3.280000e+08                    27.91                   26.71   192387           223848          223848                223848                 223848     192387       198706        198706  Press After Possession Loss              61              61                   NaN                     NaN                NaN                        NaN        NaN     Slow Build Up          Possession              71                   3            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 37       95            /team/95/leicester-city/230009            23            9       2023-01-13            Leicester City         13          Premier League           1.0              14          England       79      80        80       78    896460                    King Power Stadium          14                       6                6.0                  NaN    8.823000e+08                    26.45                   25.42   169588           220697          220697                220697                 220697     216393       220697        220697                     Balanced              41              51                   NaN                     NaN                NaN                        NaN        NaN     Slow Build Up          Possession              51                   4            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 38      234                  /team/234/benfica/230009            23            9       2023-01-13                   Benfica        308           Liga Portugal           1.0              38         Portugal       79      80        79       78    883017                        Estádio da Luz         236                       6               10.0                  NaN    3.200000e+08                    25.18                   24.69   192366           210035          210035                210035                 210035     212814       212814        236632  Press After Possession Loss              51              71                   NaN                     NaN                NaN                        NaN        NaN          Balanced            Balanced              61                   4            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 39      448            /team/448/athletic-club/230009            23            9       2023-01-13             Athletic Club         53                 La Liga           1.0              45            Spain       79      80        78       79    470943                     Estadio San Mamés         457                       5                7.0                  NaN    2.500000e+08                    27.09                   25.93   189575           189575          189575                189575                 189575     216201       189575        189575                     Balanced              51              51                   NaN                     NaN                NaN                        NaN        NaN     Fast Build Up        Forward Runs              71                   5            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 40      449               /team/449/real-betis/230009            23            9       2023-01-13                Real Betis         53                 La Liga           1.0              45            Spain       79      80        81       78    523898             Estadio Benito Villamarín         481                       3                6.0                  NaN    1.750000e+08                    28.73                   26.73   190286           216594          190286                216594                 216594     224179       216594        190286  Press After Possession Loss              61              71                   NaN                     NaN                NaN                        NaN        NaN     Slow Build Up          Possession              61                   7            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 41     1331                 /team/1331/denmark/230009            23            9       2023-01-13                   Denmark         78  Friendly International           NaN              13          Denmark       79      76        82       78    458506     Eastpoint Arena (Football Ground)        1363                       6                NaN                  NaN             NaN                    27.73                   27.30   179645           190460          190460                190460                 190460     190460       190460        190460                     Balanced              51              61                   NaN                     NaN                NaN                        NaN        NaN     Slow Build Up          Possession              51                   5            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 42       23  /team/23/borussia-monchengladbach/230009            23            9       2023-01-13  Borussia Mönchengladbach         19              Bundesliga           1.0              21          Germany       78      79        78       76    460535                         BORUSSIA-PARK          31                       5                5.0                  NaN    3.339000e+08                    26.73                   24.27   187072           187072          210324                210324                 187072     224196       210324        210324                     Balanced              61              61                   NaN                     NaN                NaN                        NaN        NaN     Slow Build Up          Possession              61                   7            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 43       66        /team/66/olympique-lyonnais/230009            23            9       2023-01-13        Olympique Lyonnais         16                 Ligue 1           1.0              18           France       78      78        76       77  37438919                      Groupama Stadium        1819                       6                8.0                  NaN    3.000000e+08                    25.73                   24.22   193301           193301          213874                193301                 193301     193301       247641        247641      Pressure On Heavy Touch              51              51                   NaN                     NaN                NaN                        NaN        NaN     Slow Build Up          Possession              51                   6            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 44      110  /team/110/wolverhampton-wanderers/230009            23            9       2023-01-13   Wolverhampton Wanderers         13          Premier League           1.0              14          England       78      78        79       74    474728                      Molineux Stadium         109                       4                5.0                  NaN    4.165000e+08                    26.36                   23.48   224293           162347          162347                162347                 162347     224293       162347        162347                     Balanced              61              51                   NaN                     NaN                NaN                        NaN        NaN     Fast Build Up        Forward Runs              61                   3            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 45      219      /team/219/olympique-marseille/230009            23            9       2023-01-13       Olympique Marseille         16                 Ligue 1           1.0              18           France       78      79        78       76    407845                      Orange Vélodrome          73                       6                8.0                  NaN    2.500000e+08                    27.55                   23.36   223874           177388          239093                177388                 177388     184941       177388        239093      Pressure On Heavy Touch              61              51                   NaN                     NaN                NaN                        NaN        NaN     Fast Build Up        Forward Runs              61                   4            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 46      236                    /team/236/porto/230009            23            9       2023-01-13                     Porto        308           Liga Portugal           1.0              38         Portugal       78      80        78       76    523928                     Estádio do Dragão         234                       7               10.0                  NaN    2.400000e+08                    26.27                   25.50   120533           210411          210411                210411                 210411     241788       210411        210411  Press After Possession Loss              51              61                   NaN                     NaN                NaN                        NaN        NaN          Balanced            Balanced              61                   6            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 47      237              /team/237/sporting-cp/230009            23            9       2023-01-13               Sporting CP        308           Liga Portugal           1.0              38         Portugal       78      78        78       79    158158         Waldstadion (Fussballstadion)         234                       4                9.0                  NaN    2.200000e+08                    25.36                   23.43   197655           240950          240950                240950                 240950     240950       243576        240950      Pressure On Heavy Touch              51              61                   NaN                     NaN                NaN                        NaN        NaN         Long Ball      Direct Passing              61                   5            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 48      245                     /team/245/ajax/230009            23            9       2023-01-13                      Ajax         10              Eredivisie           1.0              34      Netherlands       78      80        78       76     23435                   Johan Cruijff ArenA         246                       7               10.0                  NaN    4.820000e+08                    25.00                   23.23   199434           199434          199434                199434                 199434     199434       225953        199434                     Balanced              61              81                   NaN                     NaN                NaN                        NaN        NaN     Slow Build Up          Possession              71                   8            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
# 49      457            /team/457/real-sociedad/230009            23            9       2023-01-13             Real Sociedad         53                 La Liga           1.0              45            Spain       78      77        80       78    530755                           Reale Arena         448                       4                7.0                  NaN    1.500000e+08                    26.18                   23.82   225193           168542          225193                168542                 168542     225193       168542        168542                     Balanced              41              51                   NaN                     NaN                NaN                        NaN        NaN     Slow Build Up          Possession              61                   6            3               3                  NaN                      NaN                    NaN                        NaN                      NaN                       NaN                       NaN
#
#     chance_creation_positioning
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8                           NaN
# 9                           NaN
# 10                          NaN
# 11                          NaN
# 12                          NaN
# 13                          NaN
# 14                          NaN
# 15                          NaN
# 16                          NaN
# 17                          NaN
# 18                          NaN
# 19                          NaN
# 20                          NaN
# 21                          NaN
# 22                          NaN
# 23                          NaN
# 24                          NaN
# 25                          NaN
# 26                          NaN
# 27                          NaN
# 28                          NaN
# 29                          NaN
# 30                          NaN
# 31                          NaN
# 32                          NaN
# 33                          NaN
# 34                          NaN
# 35                          NaN
# 36                          NaN
# 37                          NaN
# 38                          NaN
# 39                          NaN
# 40                          NaN
# 41                          NaN
# 42                          NaN
# 43                          NaN
# 44                          NaN
# 45                          NaN
# 46                          NaN
# 47                          NaN
# 48                          NaN
# 49                          NaN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# Set up display options
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 1000)

# Load the datasets
coaches = pd.read_csv("C:/Users/hamou/Downloads/data/male_coaches.csv")
teams = pd.read_csv("C:/Users/hamou/Downloads/data/male_teams.csv")

# Display basic info
print("Coaches dataset shape:", coaches.shape)
print("Teams dataset shape:", teams.shape)
# Out:
# C:\Users\hamou\AppData\Local\Temp\ipykernel_7332\3269466340.py:13: DtypeWarning: Columns (32,38,39,40,41,49,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   teams = pd.read_csv("C:/Users/hamou/Downloads/data/male_teams.csv")
# Coaches dataset shape: (1155, 8)
# Teams dataset shape: (385055, 54)

# %%
# Explore coaches data
print("\nCoaches data columns:")
print(coaches.columns.tolist())
print("\nMissing values in coaches data:")
print(coaches.isnull().sum())

# Explore teams data
print("\nTeams data columns:")
print(teams.columns.tolist())
print("\nMissing values in teams data:")
print(teams.isnull().sum())

# Clean coaches data
# Convert dob to age
current_year = datetime.now().year
coaches['age'] = pd.to_datetime(coaches['dob']).dt.year.apply(lambda x: current_year - x)

# Drop columns with high missing values or less relevance
coaches_clean = coaches.drop(['face_url', 'coach_url'], axis=1)

# Clean teams data
# Identify columns with all null values
null_columns = teams.columns[teams.isnull().all()]
teams_clean = teams.drop(null_columns, axis=1)

# Keep only relevant columns for our analysis
relevant_team_columns = [
    'team_id', 'team_name', 'league_name', 'league_level', 
    'nationality_name', 'overall', 'attack', 'midfield', 
    'defence', 'coach_id', 'international_prestige', 
    'domestic_prestige', 'starting_xi_average_age', 
    'whole_team_average_age'
]
teams_clean = teams_clean[relevant_team_columns]

# Display cleaned data
print("\nCleaned coaches data shape:", coaches_clean.shape)
print("Cleaned teams data shape:", teams_clean.shape)
# Out:
# Coaches data columns:
# ['coach_id', 'coach_url', 'short_name', 'long_name', 'dob', 'nationality_id', 'nationality_name', 'face_url']
#
# Missing values in coaches data:
# coach_id              0
# coach_url             0
# short_name            0
# long_name             0
# dob                  83
# nationality_id        0
# nationality_name      0
# face_url            805
# dtype: int64
#
# Teams data columns:
# ['team_id', 'team_url', 'fifa_version', 'fifa_update', 'fifa_update_date', 'team_name', 'league_id', 'league_name', 'league_level', 'nationality_id', 'nationality_name', 'overall', 'attack', 'midfield', 'defence', 'coach_id', 'home_stadium', 'rival_team', 'international_prestige', 'domestic_prestige', 'transfer_budget_eur', 'club_worth_eur', 'starting_xi_average_age', 'whole_team_average_age', 'captain', 'short_free_kick', 'long_free_kick', 'left_short_free_kick', 'right_short_free_kick', 'penalties', 'left_corner', 'right_corner', 'def_style', 'def_team_width', 'def_team_depth', 'def_defence_pressure', 'def_defence_aggression', 'def_defence_width', 'def_defence_defender_line', 'off_style', 'off_build_up_play', 'off_chance_creation', 'off_team_width', 'off_players_in_box', 'off_corners', 'off_free_kicks', 'build_up_play_speed', 'build_up_play_dribbling', 'build_up_play_passing', 'build_up_play_positioning', 'chance_creation_passing', 'chance_creation_crossing', 'chance_creation_shooting', 'chance_creation_positioning']
#
# Missing values in teams data:
# team_id                             0
# team_url                            0
# fifa_version                        0
# fifa_update                         0
# fifa_update_date                    0
# team_name                           0
# league_id                           0
# league_name                         0
# league_level                    25879
# nationality_id                      0
# nationality_name                    0
# overall                             0
# attack                              0
# midfield                            0
# defence                             0
# coach_id                         2328
# home_stadium                      288
# rival_team                          0
# international_prestige              0
# domestic_prestige               25829
# transfer_budget_eur             31922
# club_worth_eur                  94962
# starting_xi_average_age             0
# whole_team_average_age              0
# captain                           444
# short_free_kick                   478
# long_free_kick                    573
# left_short_free_kick              573
# right_short_free_kick             513
# penalties                         533
# left_corner                       454
# right_corner                      348
# def_style                      195025
# def_team_width                 195025
# def_team_depth                 195025
# def_defence_pressure           142494
# def_defence_aggression         142494
# def_defence_width              142494
# def_defence_defender_line      142494
# off_style                      247821
# off_build_up_play              332259
# off_chance_creation            332259
# off_team_width                 195025
# off_players_in_box             195025
# off_corners                    195025
# off_free_kicks                 195025
# build_up_play_speed            142494
# build_up_play_dribbling        142494
# build_up_play_passing          142494
# build_up_play_positioning      142494
# chance_creation_passing        142494
# chance_creation_crossing       142494
# chance_creation_shooting       142494
# chance_creation_positioning    142494
# dtype: int64
#
# Cleaned coaches data shape: (1155, 7)
# Cleaned teams data shape: (385055, 14)

# %%
# Merge datasets on coach_id
merged_data = pd.merge(teams_clean, coaches_clean, on='coach_id', how='left')

# Calculate some new features
# Coach's experience (simplified as age for now)
merged_data['coach_experience'] = merged_data['age']

# Team quality metrics
merged_data['team_quality_ratio'] = merged_data['overall'] / (merged_data['attack'] + merged_data['midfield'] + merged_data['defence'])

# Nationality alignment (whether coach and team share nationality)
merged_data['nationality_alignment'] = (merged_data['nationality_name_x'] == merged_data['nationality_name_y']).astype(int)

# Display merged data
print("\nMerged data shape:", merged_data.shape)
print("Merged data columns:", merged_data.columns.tolist())
# Out:
# Merged data shape: (385055, 23)
# Merged data columns: ['team_id', 'team_name', 'league_name', 'league_level', 'nationality_name_x', 'overall', 'attack', 'midfield', 'defence', 'coach_id', 'international_prestige', 'domestic_prestige', 'starting_xi_average_age', 'whole_team_average_age', 'short_name', 'long_name', 'dob', 'nationality_id', 'nationality_name_y', 'age', 'coach_experience', 'team_quality_ratio', 'nationality_alignment']

# %%
# For this exercise, we'll define success as:
# 1. Team overall rating (continuous)
# 2. Top tier classification (binary - above/below median)

median_overall = merged_data['overall'].median()
merged_data['success_top_tier'] = (merged_data['overall'] >= median_overall).astype(int)

print("\nSuccess metric distribution:")
print(merged_data['success_top_tier'].value_counts())
# Out:
# Success metric distribution:
# success_top_tier
# 1    193784
# 0    191271
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


# Select features and target
features = [
    'coach_experience', 'nationality_alignment',
    'international_prestige', 'domestic_prestige',
    'starting_xi_average_age', 'whole_team_average_age'
]
# 1. Ratio between international and domestic prestige
merged_data['prestige_ratio'] = (
    merged_data['international_prestige'] / (merged_data['domestic_prestige'] + 1)
)

# 2. Experience-to-age ratio (proxy for longevity vs recency)
merged_data['experience_ratio'] = (
    merged_data['coach_experience'] / merged_data['whole_team_average_age']
)

# 3. Difference between starting XI and total team age
merged_data['age_gap'] = (
    merged_data['starting_xi_average_age'] - merged_data['whole_team_average_age']
)

# Add to your features
features += ['prestige_ratio', 'experience_ratio', 'age_gap']

target_continuous = 'overall'
target_binary = 'success_top_tier'

X = merged_data[features]
y_continuous = merged_data[target_continuous]
y_binary = merged_data[target_binary]

# Handle missing values if any
X = X.fillna(X.mean())

# Split data
X_train, X_test, y_train_cont, y_test_cont, y_train_bin, y_test_bin = train_test_split(
    X, y_continuous, y_binary, test_size=0.2, random_state=42
)

# Scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print("\nTraining data shape:", X_train.shape)
print("Test data shape:", X_test.shape)
# Out:
# Training data shape: (308044, 9)
# Test data shape: (77011, 9)

# %%
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import mean_squared_error, accuracy_score, classification_report

# --- Random Forest Regression ---
print("\nRandom Forest Regression (predicting overall)...")
rf_reg = RandomForestRegressor(random_state=42)
rf_reg.fit(X_train_scaled, y_train_cont)
y_pred_rf = rf_reg.predict(X_test_scaled)
mse_rf = mean_squared_error(y_test_cont, y_pred_rf)
print(f"Random Forest MSE: {mse_rf:.2f}")

# --- Random Forest Classification ---
print("\nRandom Forest Classification (predicting top tier success)...")
rf_clf = RandomForestClassifier(
    random_state=42,
    max_depth=13,
    min_samples_split=55,
    n_estimators=200
)
rf_clf.fit(X_train_scaled, y_train_bin)
y_pred_rf_clf = rf_clf.predict(X_test_scaled)
acc_rf = accuracy_score(y_test_bin, y_pred_rf_clf)
print(f"Random Forest Accuracy: {acc_rf:.2f}")
print("\nClassification Report for Random Forest:")
print(classification_report(y_test_bin, y_pred_rf_clf))
# Out:
# Random Forest Regression (predicting overall)...
# Random Forest MSE: 0.40
#
# Random Forest Classification (predicting top tier success)...
# Random Forest Accuracy: 0.89
#
# Classification Report for Random Forest:
#               precision    recall  f1-score   support
#
#            0       0.87      0.92      0.89     38188
#            1       0.92      0.86      0.89     38823
#
#     accuracy                           0.89     77011
#    macro avg       0.89      0.89      0.89     77011
# weighted avg       0.89      0.89      0.89     77011

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import mean_squared_error, accuracy_score, classification_report

# --- Linear Regression ---
print("\nLinear Regression (predicting overall)...")
lr = LinearRegression()
lr.fit(X_train_scaled, y_train_cont)
y_pred_lr = lr.predict(X_test_scaled)
mse_lr = mean_squared_error(y_test_cont, y_pred_lr)
print(f"Linear Regression MSE: {mse_lr:.2f}")

# --- Logistic Regression ---
print("\nLogistic Regression (predicting top tier success)...")
logreg = LogisticRegression()
logreg.fit(X_train_scaled, y_train_bin)
y_pred_log = logreg.predict(X_test_scaled)
acc_log = accuracy_score(y_test_bin, y_pred_log)
print(f"Logistic Regression Accuracy: {acc_log:.2f}")
print("\nClassification Report for Logistic Regression:")
print(classification_report(y_test_bin, y_pred_log))
# Out:
# Linear Regression (predicting overall)...
# Linear Regression MSE: 19.78
#
# Logistic Regression (predicting top tier success)...
# Logistic Regression Accuracy: 0.67
#
# Classification Report for Logistic Regression:
#               precision    recall  f1-score   support
#
#            0       0.64      0.75      0.69     38188
#            1       0.70      0.59      0.64     38823
#
#     accuracy                           0.67     77011
#    macro avg       0.67      0.67      0.67     77011
# weighted avg       0.67      0.67      0.67     77011

# %%
train_acc_rf = accuracy_score(y_train_bin, rf_clf.predict(X_train_scaled))
print(f"Training Accuracy: {train_acc_rf:.2f}")
print(f"Testing Accuracy: {acc_rf:.2f}")
# Out:
# Training Accuracy: 0.90
# Testing Accuracy: 0.89

# %%
print(merged_data[['overall', 'team_quality_ratio']].corr())
# Out:
#                      overall  team_quality_ratio
# overall             1.000000           -0.038212
# team_quality_ratio -0.038212            1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Correlation with overall (to see what's still suspicious)
corrs = merged_data[features + ['overall']].corr()['overall'].sort_values(ascending=False)
print(corrs)
# Out:
# overall                    1.000000
# international_prestige     0.517685
# prestige_ratio             0.414580
# domestic_prestige          0.257345
# whole_team_average_age     0.188493
# coach_experience           0.173512
# starting_xi_average_age    0.166146
# experience_ratio           0.091697
# age_gap                    0.000074
# nationality_alignment     -0.085076
# Name: overall, dtype: float64

# %%
# Get feature importances
feature_importances = pd.DataFrame({
    'Feature': features,
    'Importance': rf_clf.feature_importances_
}).sort_values('Importance', ascending=False)

print("\nFeature Importances:")
print(feature_importances)

# Plot feature importances
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importances)
plt.title('Feature Importances for Coach Success Prediction')
plt.show()
# Out:
# Feature Importances:
#                    Feature  Importance
# 2   international_prestige    0.212227
# 6           prestige_ratio    0.177753
# 3        domestic_prestige    0.138942
# 0         coach_experience    0.136566
# 7         experience_ratio    0.112314
# 5   whole_team_average_age    0.102571
# 4  starting_xi_average_age    0.053121
# 8                  age_gap    0.039292
# 1    nationality_alignment    0.027214

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(
    random_state=42,
    max_depth=8,
    learning_rate=0.1,
    n_estimators=200,
    subsample=0.8,
    colsample_bytree=0.8,
    use_label_encoder=False,
    eval_metric='logloss'
)
xgb.fit(X_train_scaled, y_train_bin)
y_pred_xgb = xgb.predict(X_test_scaled)
acc_xgb = accuracy_score(y_test_bin, y_pred_xgb)

print(f"\nXGBoost Accuracy: {acc_xgb:.2f}")
print("\nXGBoost Classification Report:")
print(classification_report(y_test_bin, y_pred_xgb))
# Out:
# c:\Users\hamou\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\training.py:183: UserWarning: [11:04:45] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBoost Accuracy: 0.93
#
# XGBoost Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.93     38188
#            1       0.94      0.91      0.93     38823
#
#     accuracy                           0.93     77011
#    macro avg       0.93      0.93      0.93     77011
# weighted avg       0.93      0.93      0.93     77011

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Function to get metrics
def get_metrics(y_true, y_pred, model_name):
    return {
        "Model": model_name,
        "Accuracy": accuracy_score(y_true, y_pred),
        "Precision": precision_score(y_true, y_pred),
        "Recall": recall_score(y_true, y_pred),
        "F1 Score": f1_score(y_true, y_pred)
    }

# Collect metrics
results = [
    get_metrics(y_test_bin, y_pred_log, "Logistic Regression"),
    get_metrics(y_test_bin, y_pred_rf_clf, "Random Forest"),
    get_metrics(y_test_bin, y_pred_xgb, "XGBoost")
]

# Display as DataFrame
results_df = pd.DataFrame(results)
print("\nModel Comparison:")
print(results_df.sort_values(by="F1 Score", ascending=False).round(3))
# Out:
# Model Comparison:
#                  Model  Accuracy  Precision  Recall  F1 Score
# 2              XGBoost     0.927      0.944   0.910     0.927
# 1        Random Forest     0.892      0.918   0.864     0.890
# 0  Logistic Regression     0.669      0.704   0.591     0.643

# %%
from sklearn.metrics import roc_curve, auc

# Get prediction probabilities
log_probs = logreg.predict_proba(X_test_scaled)[:, 1]
rf_probs = rf_clf.predict_proba(X_test_scaled)[:, 1]
xgb_probs = xgb.predict_proba(X_test_scaled)[:, 1]

# Compute ROC curves and AUCs
fpr_log, tpr_log, _ = roc_curve(y_test_bin, log_probs)
fpr_rf, tpr_rf, _ = roc_curve(y_test_bin, rf_probs)
fpr_xgb, tpr_xgb, _ = roc_curve(y_test_bin, xgb_probs)

auc_log = auc(fpr_log, tpr_log)
auc_rf = auc(fpr_rf, tpr_rf)
auc_xgb = auc(fpr_xgb, tpr_xgb)

# Plot ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr_log, tpr_log, label=f"Logistic Regression (AUC = {auc_log:.2f})")
plt.plot(fpr_rf, tpr_rf, label=f"Random Forest (AUC = {auc_rf:.2f})")
plt.plot(fpr_xgb, tpr_xgb, label=f"XGBoost (AUC = {auc_xgb:.2f})")
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.title("ROC Curve Comparison")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Random Forest Feature Importance
importances_rf = rf_clf.feature_importances_
features_rf = pd.Series(importances_rf, index=X.columns).sort_values(ascending=True)

# XGBoost Feature Importance
importances_xgb = xgb.feature_importances_
features_xgb = pd.Series(importances_xgb, index=X.columns).sort_values(ascending=True)

# Plot
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

features_rf.plot(kind='barh', ax=axes[0], title='Random Forest Feature Importance', color='skyblue')
features_xgb.plot(kind='barh', ax=axes[1], title='XGBoost Feature Importance', color='salmon')

plt.tight_layout()
plt.show()

# %%
results_df.set_index("Model")[["Accuracy", "Precision", "Recall", "F1 Score"]].plot(
    kind="bar", figsize=(10, 6), colormap="viridis", edgecolor='black'
)
plt.title("Model Performance Comparison")
plt.ylabel("Score")
plt.ylim(0.5, 1.0)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics.pairwise import cosine_similarity
def recommend_coaches_with_model(team_need, model, n=5):
    team_need_df = pd.DataFrame([team_need])
    for feature in features:
        if feature not in team_need_df:
            team_need_df[feature] = coach_profiles_filled[feature].mean()
    team_need_df = team_need_df[features]
    team_need_scaled = scaler.transform(team_need_df)
    
    coach_profiles_scaled = scaler.transform(coach_profiles_filled)
    
    probs = model.predict_proba(coach_profiles_scaled)[:, 1]  # Probability of success
    similarities = cosine_similarity(team_need_scaled, coach_profiles_scaled)[0]
    
    recommendations = pd.DataFrame({
        'coach_id': coach_profiles_filled.index.get_level_values('coach_id'),
        'coach_name': coach_profiles_filled.index.get_level_values('short_name'),
        'success_prob': probs,
        'similarity_score': similarities
    })

    # Sort by combination of success prob + similarity
    recommendations['combined_score'] = 0.5 * recommendations['success_prob'] + 0.5 * recommendations['similarity_score']
    return recommendations.sort_values('combined_score', ascending=False).head(n)

# %%
# Assuming you already have merged_data and features list
coach_profiles = merged_data.groupby(['coach_id', 'short_name'])[features].mean()
coach_profiles_filled = coach_profiles.fillna(coach_profiles.mean())
example_team_need = {
    'coach_experience': 10,
    'team_quality_ratio': 0.33,
    'nationality_alignment': 1,
    'international_prestige': 8,
    'domestic_prestige': 7,
    'starting_xi_average_age': 27,
    'whole_team_average_age': 25
}

print("\n🔍 Recommendations using Logistic Regression:")
print(recommend_coaches_with_model(example_team_need, logreg))

print("\n🌲 Recommendations using Random Forest:")
print(recommend_coaches_with_model(example_team_need, rf_clf))

print("\n🚀 Recommendations using XGBoost:")
print(recommend_coaches_with_model(example_team_need, xgb))
# Out:
# 🔍 Recommendations using Logistic Regression:
#      coach_id     coach_name  success_prob  similarity_score  combined_score
# 449  458813.0  J. Nagelsmann      0.912811          0.572996        0.742903
# 174  127611.0     L. Scaloni      0.973920          0.415534        0.694727
# 188  128851.0        F. Gago      0.763964          0.612663        0.688314
# 220  171254.0   A. Storozhuk      0.777706          0.558181        0.667944
# 227  184942.0   X. Hernández      0.923091          0.404713        0.663902
#
# 🌲 Recommendations using Random Forest:
#      coach_id     coach_name  success_prob  similarity_score  combined_score
# 9       270.0      G. O'Neil      0.883443          0.620570        0.752006
# 188  128851.0        F. Gago      0.875557          0.612663        0.744110
# 56     4115.0       N. Şahin      0.880893          0.595373        0.738133
# 449  458813.0  J. Nagelsmann      0.880339          0.572996        0.726668
# 7       236.0     V. Kompany      0.935402          0.505895        0.720648
#
# 🚀 Recommendations using XGBoost:
#       coach_id         coach_name  success_prob  similarity_score  combined_score
# 797  1553235.0  L. Batalha Freire      0.973676          0.720303        0.846990
# 188   128851.0            F. Gago      0.978190          0.612663        0.795426
# 9        270.0          G. O'Neil      0.953193          0.620570        0.786881
# 56      4115.0           N. Şahin      0.967512          0.595373        0.781442
# 449   458813.0      J. Nagelsmann      0.982038          0.572996        0.777517

# %%
# Get recommendations using XGBoost
top_xgb_recommendations = recommend_coaches_with_model(example_team_need, xgb)

# Get the first recommended coach
top_coach_id = top_xgb_recommendations.iloc[0]['coach_id']
top_coach_name = top_xgb_recommendations.iloc[0]['coach_name']

print(f"\n🎯 Top recommended coach by XGBoost: {top_coach_name} (ID: {int(top_coach_id)})")

# Display all attributes for this coach (use merged_data or coach_profiles)
top_coach_data = merged_data[merged_data['coach_id'] == top_coach_id]

# If multiple rows exist (e.g., for different teams), average or display a few
print("\n📋 Attributes of the top coach:")
print(top_coach_data[features + ['short_name']].drop_duplicates().head())
# Out:
# 🎯 Top recommended coach by XGBoost: L. Batalha Freire (ID: 1553235)
#
# 📋 Attributes of the top coach:
#        coach_experience  nationality_alignment  international_prestige  domestic_prestige  starting_xi_average_age  whole_team_average_age  prestige_ratio  experience_ratio  age_gap         short_name
# 219                30.0                      1                       2                3.0                    26.64                   26.23        0.500000          1.143729     0.41  L. Batalha Freire
# 933                30.0                      1                       2                3.0                    26.64                   26.04        0.500000          1.152074     0.60  L. Batalha Freire
# 2360               30.0                      1                       2                3.0                    26.55                   26.04        0.500000          1.152074     0.51  L. Batalha Freire
# 5965               30.0                      1                       2                3.0                    27.18                   25.96        0.500000          1.155624     1.22  L. Batalha Freire
# 53007              30.0                      1                       2                6.0                    27.27                   25.17        0.285714          1.191895     2.10  L. Batalha Freire

# %%
top_coach = merged_data[merged_data['coach_id'] == top_coach_id].iloc[0]
comparison = {
    'Feature': list(example_team_need.keys()),
    'Team Need': list(example_team_need.values()),
    'Coach Profile': [
        top_coach['coach_experience'],
        top_coach['team_quality_ratio'],
        top_coach['nationality_alignment'],
        top_coach['international_prestige'],
        top_coach['domestic_prestige'],
        top_coach['starting_xi_average_age'],
        top_coach['whole_team_average_age']
    ]
}

import pandas as pd
df_comparison = pd.DataFrame(comparison)
print(df_comparison)
# Out:
#                    Feature  Team Need  Coach Profile
# 0         coach_experience      10.00      30.000000
# 1       team_quality_ratio       0.33       0.333333
# 2    nationality_alignment       1.00       1.000000
# 3   international_prestige       8.00       2.000000
# 4        domestic_prestige       7.00       3.000000
# 5  starting_xi_average_age      27.00      26.640000
# 6   whole_team_average_age      25.00      26.230000

# %%
import matplotlib.pyplot as plt
import pandas as pd

def plot_team_vs_coach(team_need, merged_data, coach_id):
    # Ensure coach_id column is the correct type (float or int)
    merged_data['coach_id'] = merged_data['coach_id'].astype(float)

    # Check if coach exists
    if coach_id not in merged_data['coach_id'].values:
        print(f"❌ Coach with ID {coach_id} not found in the data.")
        return

    # Get coach row
    top_coach = merged_data[merged_data['coach_id'] == coach_id].iloc[0]

    # Extract matching features
    try:
        top_coach_profile = {k: top_coach[k] for k in team_need}
    except KeyError as e:
        print(f"❌ Missing feature in dataset: {e}")
        return

    # Build comparison DataFrame
    comparison_df = pd.DataFrame({
        'Feature': list(team_need.keys()),
        'Team Need': list(team_need.values()),
        'Top Coach': list(top_coach_profile.values())
    })

    # Plotting
    fig, ax = plt.subplots(figsize=(10, 6))
    bar_width = 0.35
    index = range(len(comparison_df))

    ax.bar(index, comparison_df['Team Need'], bar_width, label='Team Need', color='skyblue')
    ax.bar([i + bar_width for i in index], comparison_df['Top Coach'], bar_width, label='Top Coach', color='orange')

    ax.set_xlabel('Features')
    ax.set_ylabel('Values')
    ax.set_title('Comparison of Team Needs vs. Top Recommended Coach (XGBoost)')
    ax.set_xticks([i + bar_width / 2 for i in index])
    ax.set_xticklabels(comparison_df['Feature'], rotation=45, ha='right')
    ax.legend()

    plt.tight_layout()
    plt.show()
plot_team_vs_coach(example_team_need, merged_data, top_coach_id)
